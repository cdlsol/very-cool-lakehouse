# %%
from pyspark.sql import SparkSession

spark = (
    SparkSession.builder
    .remote("sc://localhost:15002")
    .getOrCreate()
)

# %%
spark.read.format("parquet").load("ofs://om/lakehouse/staging/users.parquet").show()
# Out:
# +-------+---+
# |   name| id|
# +-------+---+
# |Charlie|  3|
# |  Alice|  1|
# |    Bob|  2|
# +-------+---+
